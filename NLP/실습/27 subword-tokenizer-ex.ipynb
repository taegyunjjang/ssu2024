# %%
# !pip install transformers==4.45.2

# %%
from transformers import AutoTokenizer
from pprint import pprint
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
tokenizer = AutoTokenizer.from_pretrained("klue/roberta-base")
# Out:
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# C:\Users\bywor\anaconda3\envs\intro_ai\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\bywor\.cache\huggingface\hub\models--klue--roberta-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/752k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]

# %%
sentences = [
    "아 더빙.. 진짜 짜증나네요 목소리",
    "흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나",
    "별루 였다..",
]
tokenized_sentences = [tokenizer.tokenize(sentence) for sentence in sentences]

# %%
pprint(tokenized_sentences)
# Out:
# [['아', '더', '##빙', '.', '.', '진짜', '짜증', '##나', '##네', '##요', '목소리'],
#  ['흠',
#   '.',
#   '.',
#   '.',
#   '포스터',
#   '##보',
#   '##고',
#   '초딩',
#   '##영화',
#   '##줄',
#   '.',
#   '.',
#   '.',
#   '.',
#   '오버',
#   '##연',
#   '##기',
#   '##조',
#   '##차',
#   '가볍',
#   '##지',
#   '않',
#   '##구나'],
#  ['별', '##루', '였', '##다', '.', '.']]

# %%
tokenizer.vocab
# Out:
# {'넘어': 4587,
#  '아토피': 14845,
#  '뭉': 1096,
#  '##갯짓': 29088,
#  '국영': 14474,
#  '민감': 7198,
#  '오수': 23839,
#  '육체': 7411,
#  '깨진': 21377,
#  '승합차': 29182,
#  '꼬이': 26725,
#  '전유물': 24968,
#  '공보': 14627,
#  '##iff': 20970,
#  '알프스': 20922,
#  '어기': 15158,
#  '##님': 2098,
#  '출판물': 28513,
#  '유쾌': 10960,
#  '나오': 3853,
#  '화보': 10879,
#  '##다임': 9767,
#  '##튕': 3518,
#  '공헌': 7021,
#  '##루스': 15030,
#  '끝낼': 22151,
#  '뿜': 1227,
#  '상업': 6195,
#  '타계': 25804,
#  '꾸': 689,
#  '##내': 2369,
#  '회원국': 10740,
#  '회신': 27943,
#  '풍족': 25189,
#  '뭉치': 15077,
#  'ㆍ외': 24417,
#  '대부분': 4057,
#  '오타': 17673,
#  '##자유': 12342,
#  'CNS': 30433,
#  '##모토': 14257,
#  '공간': 4101,
#  '바다': 4822,
#  '잔고': 25504,
#  '想': 357,
#  '총력전': 22911,
#  '##티나': 9688,
#  '즐긴다': 21589,
#  '갓': 551,
#  '더라구': 20663,
#  '기절': 19087,
#  '창사': 23339,
#  '##ose': 20027,
#  '편의점': 8187,
#  '명단': 7824,
#  '도하': 26081,
#  '유니버': 16780,
#  '##p': 2006,
#  '물리학자': 22940,
#  '선크림': 22869,
#  '울진군': 30950,
#  '샤를': 26747,
#  '촘촘': 17522,
#  '보궐': 12244,
#  '##옴': 2721,
#  '##🏻🏻': 29210,
#  '##😭': 2676,
#  '##ru': 26395,
#  '•': 118,
#  '값싼': 19793,
#  '##ization': 17906,
#  '보충': 9084,
#  '화성': 6835,
#  '발산': 13458,
#  '유현': 28227,
#  '맞잡': 27850,
#  '군더': 30786,
#  '도망가': 15002,
#  '천진': 19628,
#  '##흉': 2552,
#  '권순': 30778,
#  '##ㅣ': 2880,
#  '테크놀로지': 17333,
#  '역외': 21352,
#  '웅변': 24805,
#  '강경': 8088,
#  '이따': 11175,
#  '##사전': 16936,
#  '매경': 13648,
#  '시발': 13176,
#  '집안': 5720,
#  '對': 328,
#  '아편': 22271,
#  '이요': 22195,
#  '리라는': 13945,
#  '연말연시': 29323,
#  '사우스': 18815,
#  '교류': 5459,
#  '달구': 19268,
#  'VR': 12718,
#  '산실': 26370,
#  '고상': 19021,
#  '수험': 8287,
#  '백수': 19277,
#  '밀러': 17387,
#  '중앙지': 19460,
#  '##멧': 2910,
#  '##발': 2311,
#  '신뢰도': 14605,
#  '아늑': 21309,
#  '[unused303]': 31803,
#  '귀가': 16741,
#  '##무원': 4473,
#  '항상': 4744,
#  '해운업': 21635,
#  '투영': 20022,
#  '수비수': 12093,
#  '어떻게': 3842,
#  '##사이클': 29012,
#  '以': 232,
#  '미수': 15106,
#  '켓': 1722,
#  '통칭': 29415,
#  '동아리': 8394,
#  'JP': 19857,
#  '동선': 16653,
#  '##뛰기': 26829,
#  '실학': 24788,
#  '370': 20799,
#  '연재': 12944,
#  '##걸': 2249,
#  '말리': 10803,
#  '주지사': 18470,
#  '##제강': 21910,
#  '청해': 21359,
#  '보이': 3783,
#  '빼앗': 6838,
#  '증시': 6395,
#  '뮤지': 6035,
#  '형량': 19847,
#  '백승': 28835,
#  '물씬': 18382,
#  '##드래': 25072,
#  '수행자': 25931,
#  '여생': 29687,
#  '남방': 19119,
#  '결과물': 11693,
#  '깬': 663,
#  '이레': 30320,
#  '협회': 4760,
#  '##ero': 30354,
#  '121': 14936,
#  '꽃밭': 26275,
#  '용선': 23616,
#  '책임자': 8254,
#  '화이팅': 21121,
#  '인문': 6795,
#  '거트': 17075,
#  '놔': 774,
#  '1951': 20368,
#  '기간제': 19579,
#  '역관': 27491,
#  '줍': 1569,
#  '뒷': 874,
#  '##mt': 30630,
#  '##데자': 26881,
#  '지폐': 17410,
#  '뜨끈': 28999,
#  '토너먼트': 20849,
#  '우리나라': 7339,
#  '태수': 25831,
#  '초라': 13857,
#  '化': 267,
#  '해묵': 31248,
#  '덧붙이': 21571,
#  '유통망': 22416,
#  '##혜원': 28673,
#  '브로드웨이': 29262,
#  '8000': 6938,
#  '차선': 12092,
#  '예뻤': 25982,
#  '터무니': 15701,
#  'DC': 16932,
#  '무정부': 29024,
#  '와일드': 17772,
#  '서늘': 16796,
#  '저렇게': 10020,
#  '##ough': 24899,
#  '인한': 5198,
#  '늘어진': 26858,
#  '담겼': 16102,
#  '비대위': 11565,
#  '의심': 5292,
#  '뒷받침': 8082,
#  '##쿵': 3375,
#  '코스트': 19188,
#  '웨이브': 20756,
#  '찾아간': 18334,
#  '##는': 2259,
#  '승천': 31457,
#  '긴급': 6494,
#  '소풍': 18912,
#  '사격': 8953,
#  '몰이': 22305,
#  '950': 24410,
#  '550': 17458,
#  '##②': 2923,
#  '변별': 20769,
#  '광물': 15496,
#  '남정': 30721,
#  '부업': 20990,
#  '영업': 4308,
#  '정계': 13596,
#  '해법': 9382,
#  '##낮': 3264,
#  '진입': 5745,
#  '조차': 4776,
#  '용어': 6436,
#  '마이어': 26768,
#  '##아아': 16881,
#  '처해': 12588,
#  '연출가': 19698,
#  '삼가': 14866,
#  '농원': 28552,
#  '방문': 4110,
#  '팔려': 14477,
#  'Har': 17015,
#  '[unused160]': 31660,
#  '화려': 5725,
#  '살펴봐야': 24992,
#  '흉내': 12961,
#  '핵': 1898,
#  '고춧가루': 20059,
#  '하드웨어': 14651,
#  '감탄사': 27730,
#  '전군': 29904,
#  '문양': 17110,
#  '안일': 22365,
#  '전': 1537,
#  '유치장': 30624,
#  '맞섰': 17893,
#  '문화재': 7281,
#  '야전': 27447,
#  '의존도': 15440,
#  '가야': 13232,
#  '복고': 21301,
#  '곰돌이': 28077,
#  '어설픈': 24627,
#  '체득': 23088,
#  '##뢰': 2848,
#  '포수': 12111,
#  '북한산': 22211,
#  '하지원': 29346,
#  '대구': 3900,
#  '연합': 4637,
#  '국기': 14788,
#  '종금': 26297,
#  '##일러': 11687,
#  'by': 12860,
#  '##인다는': 15778,
#  '나로호': 25270,
#  '잠잠': 19412,
#  '치매': 8724,
#  '##영수': 16202,
#  '##성어': 28926,
#  '서클': 21189,
#  '처벌': 5581,
#  '몰아주': 18412,
#  '##78': 24075,
#  '㎾': 211,
#  '정작': 7261,
#  '##에너지': 27147,
#  '아닙니다': 6525,
#  '##방아': 26481,
#  '유머': 10384,
#  '시차': 19168,
#  '옥': 1444,
#  '조선조': 28403,
#  '준용': 25115,
#  '##맙': 3460,
#  '##짜': 2244,
#  '##좌': 2584,
#  '메신저': 14026,
#  '주안점': 26391,
#  '물든': 25489,
#  '합숙': 24434,
#  '##베이거스': 21631,
#  '구성원': 6719,
#  '진사': 23897,
#  '허세': 28362,
#  '##DI': 9166,
#  '개소': 7988,
#  '거침없이': 17897,
#  '##기록': 27899,
#  '##세우': 15473,
#  '체인지': 18076,
#  'one': 23828,
#  '##자치': 11282,
#  '가늘': 14784,
#  '창원': 5479,
#  '베르': 8702,
#  'JY': 20973,
#  '##픈': 2649,
#  '보선': 13986,
#  '배우': 4165,
#  '즐비': 16966,
#  '이겨': 7918,
#  'с': 109,
#  '깊숙이': 13001,
#  '##픔': 2914,
#  '걸프': 27162,
#  '안젤': 24963,
#  '쿠': 1738,
#  '스즈': 23965,
#  '달한': 28241,
#  '*': 14,
#  '##슬러': 9758,
#  '불쾌감': 25901,
#  '실생활': 19035,
#  '빨랐': 22893,
#  '##어붙': 8432,
#  '##러워': 8405,
#  '심사': 4917,
#  '공산품': 27795,
#  '##태프': 11094,
#  '대뜸': 23715,
#  '순순히': 21219,
#  '두개골': 29550,
#  '##ode': 28401,
#  '혈압': 8997,
#  '##마다': 10598,
#  '불변': 21086,
#  '##쫙': 3383,
#  '냅': 736,
#  '차근차근': 16276,
#  'produc': 31138,
#  '끗': 709,
#  '후광': 28624,
#  '##빚': 3535,
#  '닙': 806,
#  '##TI': 11026,
#  '왕따': 18149,
#  '##AS': 11648,
#  '公': 251,
#  '이불': 10810,
#  '##거나': 9253,
#  '비빔': 11783,
#  '간담회': 6361,
#  '나아갈': 14863,
#  '신체': 5878,
#  '불운': 20725,
#  '근간': 13626,
#  '경계선': 18893,
#  '##oft': 26463,
#  '민관': 15531,
#  '신흥': 10475,
#  '유료': 9967,
#  '재래': 12844,
#  '고택': 23223,
#  '때론': 16084,
#  '쓰여': 10786,
#  '##갈비': 12799,
#  '달': 814,
#  '내쉬': 11541,
#  '자꾸': 5977,
#  'et': 16971,
#  '돌파구': 16186,
#  '##닙': 3170,
#  '[unused159]': 31659,
#  '다중': 14959,
#  '##헨티나': 11184,
#  '루타': 13496,
#  '자리매김': 9973,
#  '완고': 28805,
#  '##스티누스': 30981,
#  '웅진': 13525,
#  '교우': 29265,
#  '##찌감치': 10792,
#  '물동량': 18740,
#  '선점': 11674,
#  '충성': 9394,
#  '온다고': 20309,
#  '부러진': 25005,
#  'ㅈ': 190,
#  '한단다': 26362,
#  '양형': 19439,
#  '3500': 14831,
#  '기금': 6898,
#  '##회전': 21805,
#  '[unused343]': 31843,
#  '원산지': 14467,
#  '몰려오': 25906,
#  '때로': 6918,
#  '출토': 19055,
#  '발췌': 25729,
#  '본사': 6368,
#  '공룡': 12052,
#  '지프': 22160,
#  '앞장': 7118,
#  '##파니': 21837,
#  '해골': 27021,
#  '약하': 10624,
#  '각급': 20343,
#  '[unused150]': 31650,
#  '##포동': 18837,
#  '[unused496]': 31996,
#  '환산': 13499,
#  '빈정': 28226,
#  '##ross': 25428,
#  '원리금': 19450,
#  '運': 507,
#  '막혔': 18963,
#  '양측': 9240,
#  '후드': 19330,
#  '구력': 31242,
#  '가즈': 23251,
#  '끼우': 27761,
#  '1956': 17916,
#  '가솔': 15512,
#  '통행': 9429,
#  '너무': 3760,
#  '성종': 21186,
#  '변장': 31477,
#  '##ort': 9044,
#  '턴': 1779,
#  '통할': 21673,
#  '감축': 8114,
#  '기억': 4228,
#  '미투': 19650,
#  '발부': 14536,
#  '가용': 24181,
#  '##♥': 3305,
#  '##뚜기': 18046,
#  '오비': 21907,
#  '십시오': 6513,
#  '[unused100]': 31600,
#  '##셰': 2705,
#  '불거': 8470,
#  '산나물': 30130,
#  '잔다': 25887,
#  '재력': 25007,
#  '제대': 13896,
#  '철강재': 29524,
#  '내다보': 11182,
#  '극단': 7001,
#  '울산': 4595,
#  '기우': 18695,
#  '보고회': 17024,
#  '천민': 27975,
#  ':': 30,
#  '홈런': 5874,
#  '빼먹': 26978,
#  '##놀이': 8913,
#  '오니': 23039,
#  '##프라': 5747,
#  '대교': 12116,
#  '방향': 4367,
#  '풍겼': 31479,
#  '##유국': 23110,
#  '아울렛': 16208,
#  '[unused240]': 31740,
#  '즉석': 13470,
#  '治': 416,
#  'GN': 28469,
#  'MT': 28795,
#  '##샴': 3182,
#  '다오': 31130,
#  '다신': 26024,
#  '스크랩': 23122,
#  '여운': 15987,
#  '강제': 5583,
#  '어리둥절': 18737,
#  '쁘띠': 31034,
#  '허황': 26989,
#  '청아': 30737,
#  '외할머니': 22039,
#  '할리우드': 11979,
#  '파이터': 18524,
#  '웨일': 28327,
#  '소홀히': 13515,
#  '고루': 15242,
#  '특단': 23176,
#  '치고': 22167,
#  '알루미': 13304,
#  '경락': 26751,
#  '쓸': 1366,
#  '퍼': 1844,
#  '280': 15530,
#  '올라탔': 31090,
#  '유용': 7818,
#  '출연자': 28198,
#  '해명': 6750,
#  '마리': 4915,
#  '돼온': 27383,
#  '새겨진': 15424,
#  '촉촉': 8974,
#  '그랜저': 21029,
#  '아킬': 23555,
#  '##ull': 18144,
#  '무궁': 13093,
#  '케이스': 8726,
#  '국유': 14540,
#  '생겨서': 18107,
#  'book': 28480,
#  '190': 7175,
#  'т': 110,
#  '##딘': 2695,
#  '서북': 17183,
#  '##촉': 2665,
#  '헤': 1912,
#  '총사': 19019,
#  '예고편': 24223,
#  '으면은': 16979,
#  '가람': 22149,
#  '문란': 22853,
#  '##≪': 3177,
#  '느린': 17135,
#  '아파서': 19820,
#  '성인병': 26398,
#  '##정리': 22810,
#  'Econom': 20464,
#  '멘': 1067,
#  '로얄': 23006,
#  '연작': 21370,
#  '레이싱': 19741,
#  '굵': 620,
#  '울렸': 13650,
#  '원어': 18377,
#  '모스크바': 13424,
#  '키움': 20593,
#  '루피': 31297,
#  '자본주의': 6825,
#  '두르': 18284,
#  '##피': 2263,
#  '전구': 21292,
#  '전단': 14327,
#  '본다': 4919,
#  '탕수육': 23280,
#  '무안타': 29061,
#  '[unused482]': 31982,
#  '계략': 26816,
#  '챔피': 6252,
#  '자니': 13202,
#  '건보': 30528,
#  '서둘러': 8468,
#  '생체': 14939,
#  '소장품': 30371,
#  '졸속': 23910,
#  '오로라': 28858,
#  '렀다': 10285,
#  '곰': 599,
#  '자유형': 26808,
#  '대처': 6438,
#  '집합': 12958,
#  '##시마': 9658,
#  '처음': 3790,
#  '시작': 3670,
#  '신진': 13561,
#  'LS': 12629,
#  '낮췄': 17058,
#  '삼월': 22445,
#  '상생': 7106,
#  '격변': 29106,
#  '싱크탱크': 21630,
#  '디바': 17479,
#  '##자동': 26070,
#  '중사': 25851,
#  '고만': 22333,
#  '##만치': 20455,
#  '##임즈': 31136,
#  '회계': 6223,
#  '##소시': 10431,
#  '블루투스': 20334,
#  'CEO': 6191,
#  '부가가치세': 18866,
#  '사르트르': 24629,
#  '샀': 1241,
#  '카운터': 18000,
#  '천문학': 15677,
#  '김미': 14934,
#  '##무시': 18654,
#  '프러': 28527,
#  '##티': 2747,
#  '심상': 10383,
#  '앞': 1388,
#  '단언': 16179,
#  '행자': 20115,
#  '고리': 7403,
#  '##메이': 15714,
#  '진동': 10063,
#  '##종일': 21649,
#  '佛': 234,
#  '220': 13444,
#  '막론': 15876,
#  '상향': 10113,
#  '파악': 4591,
#  '기독교인': 28132,
#  '본선': 9080,
#  '저변': 16822,
#  '火': 422,
#  '이주영': 26308,
#  '한화케미칼': 29272,
#  '高': 538,
#  '나돌': 18160,
#  '종시': 7083,
#  '숙부': 25915,
#  '십일월': 30467,
#  '㈜': 201,
#  '에쿠스': 30986,
#  '##태영': 19921,
#  '성큼': 19533,
#  '넹': 758,
#  '주관': 5973,
#  '지구촌': 14830,
#  '이젠': 7194,
#  '주안': 19164,
#  '##낙': 2921,
#  '깜박': 23865,
#  '유람선': 20880,
#  '나물': 15003,
#  '얽매이': 22841,
#  '##il': 4733,
#  '[unused279]': 31779,
#  '건장': 27977,
#  '밀크': 17067,
#  '위생': 9205,
#  '시금': 18446,
#  '되살리': 20695,
#  '유전': 8653,
#  '디딜': 29528,
#  '주체사상': 25881,
#  '벌칙': 28631,
#  '노라': 11089,
#  '박혀': 15926,
#  '흥': 1965,
#  '시댁': 21227,
#  '구세주': 29651,
#  '몹시': 8875,
#  '우도': 25765,
#  '자전거': 5655,
#  '한신': 27474,
#  '보상금': 13972,
#  '입대': 12119,
#  '세르': 13078,
#  '채무자': 13961,
#  '효성': 11326,
#  '김효': 14921,
#  '내세웠': 13057,
#  '##돗': 3488,
#  '─': 143,
#  '로우': 15913,
#  '과감': 7437,
#  '약한': 9117,
#  '수직': 10566,
#  '독서실': 25193,
#  '퍼져': 10391,
#  '체내': 14182,
#  'or': 8537,
#  '장단점': 21280,
#  '올까': 31444,
#  '조광래': 28389,
#  '157': 14516,
#  '248': 30927,
#  '놀랬': 28956,
#  '빴': 1200,
#  '평온': 15769,
#  '개관': 9244,
#  '반덤핑': 23377,
#  '안중': 14746,
#  '원세훈': 24237,
#  '국민카드': 22250,
#  '##24': 21608,
#  '强': 346,
#  '이랬': 16169,
#  '책상': 7961,
#  '하태': 25977,
#  '일문일답': 29365,
#  'IC': 6715,
#  '박윤': 31052,
#  '여야': 4833,
#  '꾸몄': 20389,
#  '연한': 19746,
#  '##려야': 6455,
#  'YMCA': 23011,
#  '목청': 21683,
#  '성완': 23014,
#  '決': 414,
#  '경로당': 18034,
#  '며칠': 6318,
#  '##lect': 21305,
#  '프라이드': 29211,
#  '헌법': 5130,
#  '나눌': 10040,
#  '##썼': 3391,
#  '고법': 16091,
#  '쓸데없': 15397,
#  '키움증권': 28136,
#  '미적': 30131,
#  '##ficial': 22018,
#  '끈다': 10038,
#  '김성태': 20058,
#  '개념': 4453,
#  '말투': 10795,
#  '##f': 2009,
#  '반짝이': 14579,
#  '소식통': 13669,
#  '하시': 29062,
#  '거둬': 13924,
#  '가까': 4269,
#  '외교관': 14805,
#  'é': 102,
#  '▲': 148,
#  '마찬가지': 4600,
#  '##꽝': 3329,
#  '##자원': 10638,
#  '##조건': 6366,
#  '202': 7735,
#  '두리번': 22564,
#  'my': 15408,
#  '노여움': 30633,
#  'gr': 23246,
#  '커다란': 6282,
#  '부풀려': 22679,
#  '힘': 1972,
#  '##런치': 16721,
#  '추상': 9348,
#  '##튿날': 13670,
#  '고구려': 7733,
#  '특위': 8641,
#  '##숫': 3186,
#  'MR': 20606,
#  '보수주의': 25880,
#  '상법': 15081,
#  '어둡': 13382,
#  '노동청': 25971,
#  '뮌': 1102,
#  '승승': 18543,
#  '휴직': 14046,
#  '얗': 1404,
#  '미완성': 30132,
#  '##찌개': 12144,
#  '때우': 27235,
#  '흘': 1961,
#  '이뤄지': 6031,
#  '해고': 7208,
#  '사외': 12702,
#  '실연': 28749,
#  '짙': 1593,
#  '전날': 5978,
#  '부위원장': 13459,
#  '헌병': 23485,
#  '야만': 16194,
#  '로드맵': 14747,
#  '이체': 19026,
#  '한국개발연구원': 25435,
#  '무작정': 14854,
#  '합류': 7468,
#  '동방신기': 28317,
#  '##냇': 3487,
#  '##세스': 24141,
#  '모녀': 18920,
#  '이문': 16149,
#  '슛': 1315,
#  '정형': 12573,
#  '위법': 10385,
#  '활용': 3987,
#  '58': 6264,
#  '묵시': 24624,
#  '인하': 5426,
#  '##랑스': 28201,
#  '##oup': 21334,
#  '[unused484]': 31984,
#  '냉난방': 30784,
#  '##직자': 8404,
#  '사임': 13563,
#  '공법': 13455,
#  '재테크': 10594,
#  '훈계': 25942,
#  '문정': 17937,
#  '##뚫': 3577,
#  '대리인': 13573,
#  '쳐다봤': 27835,
#  '##학생': 5097,
#  '건만': 14791,
#  '개소식': 22536,
#  '될까요': 14765,
#  '피시': 24641,
#  '헬리콥터': 25275,
#  '딜러': 16288,
#  '주성': 21449,
#  '##내티': 30058,
#  '준다고': 11220,
#  '##ol': 4634,
#  '라디오': 6526,
#  '만능': 17961,
#  '멘탈': 25396,
#  '##꼼': 2697,
#  '바라본다': 21478,
#  '족장': 29250,
#  '아닐지': 25673,
#  '빠진다': 19588,
#  '냉소': 17486,
#  '김재철': 23215,
#  '김치찌개': 23358,
#  '기피': 11748,
#  '공단': 5446,
#  '전격': 10235,
#  '##렁크': 20121,
#  '스테이크': 11130,
#  '주임': 16080,
#  '수치심': 23491,
#  '[unused452]': 31952,
#  '휘말리': 27063,
#  '수송': 9997,
#  '아스널': 21865,
#  '##찰청': 20809,
#  '이주민': 20471,
#  '추신': 11135,
#  '흔치': 21687,
#  '랍': 947,
#  '상서': 25533,
#  '유례없': 27791,
#  '##사태': 16123,
#  '닮': 816,
#  '[unused427]': 31927,
#  '발바닥': 19643,
#  '음악': 4152,
#  '##칩니다': 28502,
#  '##데이': 8665,
#  '##제이': 15881,
#  '박경': 13540,
#  '파이팅': 21317,
#  '##펠러': 23523,
#  '울릉': 11737,
#  '광안리': 25158,
#  '가까운': 5376,
#  '꿈틀': 16485,
#  '흘리': 7549,
#  '쓰였': 15665,
#  '##으며': 4007,
#  '키운다': 26112,
#  '관상': 15846,
#  '마니': 19655,
#  '이방': 12537,
#  '이제야': 13507,
#  '쿠데': 13098,
#  '##디아': 7970,
#  '립': 1033,
#  '임파': 31096,
#  '후반전': 27006,
#  '편했': 29529,
#  'Reg': 26984,
#  '모나': 20288,
#  '마술': 11367,
#  '본전': 25324,
#  '의약': 8663,
#  '실과': 20637,
#  '##에이': 11264,
#  '##먹': 2389,
#  '##mp': 13632,
#  '관련자': 13953,
#  '산학': 10516,
#  '카누': 24320,
#  '##밉': 3547,
#  '부흥': 13686,
#  '##덤핑': 23329,
#  '시뮬': 13959,
#  '천문대': 28694,
#  '술부': 13968,
#  '##헨': 2727,
#  '##아치': 19153,
#  '선지자': 31376,
#  '이승만': 10848,
#  '리더': 5053,
#  '비단': 9965,
#  '[unused483]': 31983,
#  '가발': 23347,
#  '열세': 17946,
#  '장마철': 23045,
#  '섣불리': 19807,
#  '요통': 31285,
#  '담당자': 8122,
#  '##듬': 2908,
#  '넷플릭스': 23026,
#  '버금': 18394,
#  '불출마': 15662,
#  '못된': 29090,
#  '퍼뜨리': 29507,
#  '건강': 3996,
#  '##캬': 3476,
#  '[unused271]': 31771,
#  '을지로': 23901,
#  '최대치': 19252,
#  '튀겨': 25668,
#  '지닌다': 16954,
#  '더러': 8841,
#  '뛰어드': 26478,
#  '이뤄지지': 10064,
#  '보장': 4651,
#  'Korea': 16280,
#  '급선무': 23683,
#  '물려받': 15115,
#  '톨': 1796,
#  '##ly': 10567,
#  '金': 1974,
#  '절박': 12739,
#  '호': 1926,
#  '을지': 5078,
#  '위시': 22185,
#  '번개': 14415,
#  '수변': 18186,
#  '근속': 24107,
#  '희소성': 29592,
#  '폭행': 7694,
#  '##췄': 3501,
#  '데드': 25777,
#  '##칙': 2426,
#  '희망자': 19030,
#  '○': 156,
#  '킬로': 9810,
#  '##샐': 2795,
#  '부정부패': 19072,
#  '고사하고': 26122,
#  '##춧가루': 18346,
#  '간극': 25812,
#  '대안': 5605,
#  '소방': 6091,
#  '골칫': 25927,
#  '느낄': 5855,
#  '배워서': 30657,
#  '독스': 31087,
#  '노승': 27929,
#  '가자': 21721,
#  '말차': 31332,
#  '헉': 1906,
#  'na': 18976,
#  '교도관': 30208,
#  '돌려야': 29935,
#  '22': 4107,
#  '벌': 1142,
#  '음반': 8842,
#  '합의': 4436,
#  '일임': 21882,
#  '##학생회': 24531,
#  '단기': 6010,
#  '죄책감': 16289,
#  '증식': 15603,
#  '맞춰져': 24438,
#  '격파': 20896,
#  '솔직히': 7946,
#  '쓴다고': 27857,
#  '##eneral': 31097,
#  '산골': 16901,
#  '변명': 10980,
#  '장외': 16007,
#  '전광판': 21218,
#  '모으': 6410,
#  '##ye': 25501,
#  '내력': 24214,
#  '##진우': 24725,
#  '런닝맨': 28190,
#  '슬로': 8530,
#  '양질': 13372,
#  '줄였': 12800,
#  '헤라': 17351,
#  '나잇': 31116,
#  '증거': 5331,
#  '찜질': 20359,
#  '등극': 15910,
#  '스타인': 27398,
#  '##연설': 24394,
#  '##니즘': 8681,
#  '알렉': 10662,
#  '구제': 6688,
#  '이조': 25227,
#  '재인': 21700,
#  '조련': 28975,
#  '##잘것없': 28234,
#  '보여야': 18937,
#  '아이슬란드': 28111,
#  '희': 1967,
#  '##암리': 26121,
#  '독일군': 26177,
#  '상쇄': 21427,
#  '무슬림': 15503,
#  '비꼬': 24702,
#  '[unused411]': 31911,
#  '상영': 8452,
#  '시장': 3648,
#  '의료인': 29305,
#  '##벚': 3316,
#  '어구': 30780,
#  '##휘': 2740,
#  '##괴': 2629,
#  '##ens': 11352,
#  '의결권': 17340,
#  '회화': 10299,
#  '##공산': 25156,
#  '##눌': 3158,
#  '찬사': 14643,
#  ...}
